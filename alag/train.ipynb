# %%
import numpy as np
from scipy.linalg import *
from sympy import *
init_printing()

# %%
A = Matrix([
    [6, 2, 5, 349],
    [9, 5, 9, 623],
    [7, 5, 3, 361]
])
Matrix.rref(A)
# Out:
# ⎛⎡1  0  0  20⎤           ⎞
# ⎜⎢           ⎥           ⎟
# ⎜⎢0  1  0  22⎥, (0, 1, 2)⎟
# ⎜⎢           ⎥           ⎟
# ⎝⎣0  0  1  37⎦           ⎠

# %% [markdown]
# # 3

# %% [markdown]
# ![](pic/train/3/1.png)

# %%
t = symbols('t')
A = Matrix([
    [5, 8, 1, 7],
    [3, 8, 7, 8],
    [8, 7, 5, 7],
    [2, 9, 8, t]
])
B = Matrix([
    [6, 9, 3, 4],
    [9, 6, 0, 4],
    [8, 1, 5, 6],
    [7, 5, 4, 9]
])
C = A*B
d = C.det()
x = solve(d, t)
x, 2153/240
# Out:
# ⎛⎡2153⎤                   ⎞
# ⎜⎢────⎥, 8.970833333333333⎟
# ⎝⎣240 ⎦                   ⎠

# %%
x = symbols('x')
M = Matrix([
    [2, 5, 0, x],
    [4, 3, 7, 3],
    [x, 7, 0, 8],
    [4, 6, 2, 4]
])
M.det()
# Out:
#       2
# - 36⋅x  + 250⋅x - 532

# %%
n = 60_000
