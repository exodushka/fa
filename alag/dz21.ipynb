# %%
import numpy as np 
import matplotlib.pyplot as plt 
from sympy import *

# %% [markdown]
# ![](pic/21/1.png)

# %%
#a 
eq1 = ((5 + I) * (7 -6*I)) / (3 + I)
eq1_alg = simplify(eq1)
eq1_mod = Abs(eq1)
eq1_arg = arg(eq1)
print(f"alg: {eq1_alg}")
print(f"mod: {eq1_mod} arg: {eq1_arg}")
print(f"trig: {eq1_mod}cos({eq1_arg}) + i*sin({eq1_arg})")
print(f"показательная: {eq1_mod}*exp(i*{eq1_arg})")
# Out:
# alg: 10 - 11*I
# mod: sqrt(221) arg: -atan(11/10)
# trig: sqrt(221)cos(-atan(11/10)) + i*sin(-atan(11/10))
# показательная: sqrt(221)*exp(i*-atan(11/10))

# %%
#b 
eq2 = ((1+I)**5) / (1 - I)**3
eq2_alg = simplify(eq2)
eq2_mod = Abs(eq2)
eq2_arg = arg(eq2)
print(f"alg: {eq2_alg}")
print(f"mod: {eq2_mod} arg: {eq2_arg}")
print(f"trig: {eq2_mod}cos({eq2_arg}) + i*sin({eq2_arg})")
print(f"показательная: {eq2_mod}*exp(i*{eq2_arg})")
# Out:
# alg: 2
# mod: 2 arg: 0
# trig: 2cos(0) + i*sin(0)
# показательная: 2*exp(i*0)

# %%
#c
eq3_left = ((-1+I*sqrt(3))**15) / ((1 - I) ** 20)
eq3_right = ((-1 -I*sqrt(3))**15) / ((1 + I) ** 20)
eq3 = eq3_left + eq3_right 
eq3_alg = simplify(eq3)
eq3_mod = Abs(eq3)
eq3_arg = arg(eq3)
print(f"alg: {eq3_alg}")
print(f"mod: {eq3_mod} arg: {eq3_arg}")
print(f"trig: {eq3_mod}cos({eq3_arg}) + i*sin({eq3_arg})")
print(f"показательная: {eq3_mod}*exp(i*{eq3_arg})")
# Out:
# alg: -64
# mod: Abs((1 - sqrt(3)*I)**15/(1 - I)**20 + (1 + sqrt(3)*I)**15/(1 + I)**20) arg: pi
# trig: Abs((1 - sqrt(3)*I)**15/(1 - I)**20 + (1 + sqrt(3)*I)**15/(1 + I)**20)cos(pi) + i*sin(pi)
# показательная: Abs((1 - sqrt(3)*I)**15/(1 - I)**20 + (1 + sqrt(3)*I)**15/(1 + I)**20)*exp(i*pi)

# %%
sqrt(3)
# Out:
# sqrt(3)

# %% [markdown]
# ![](pic/21/2.png)

# %%
#a
z = symbols("z")
eq1 = Eq(z**2 + (2*I - 7)*z + 13 - I, 0)
solution = solve(eq1, z)
solution
# Out:
# [2 + I, 5 - 3*I]

# %%
#b 
z1, z2 = symbols("z1, z2")
eq2_1 = Eq(2*z1 - (2+I)*z2, -1*I)
eq2_2 = Eq((4-2*I)*z1 -5*z2, -1 -2*I)
solution = solve([eq2_1, eq2_2], [z1,z2])
solution
# Out:
# {z1: z2*(1 + I/2) - I/2}

# %%
#e 
z = symbols("z")
eq5 = Eq(z**8, I+1)
solve(eq5, z)
# Out:
# [-2**(1/16)*sin(pi/32) + 2**(1/16)*I*cos(pi/32),
#  2**(1/16)*sin(pi/32) - 2**(1/16)*I*cos(pi/32),
#  -2**(1/16)*cos(pi/32) - 2**(1/16)*I*sin(pi/32),
#  2**(1/16)*cos(pi/32) + 2**(1/16)*I*sin(pi/32),
#  -2**(9/16)*sin(pi/32)/2 + 2**(9/16)*cos(pi/32)/2 + 2**(9/16)*I*sin(pi/32)/2 + 2**(9/16)*I*cos(pi/32)/2,
#  2**(9/16)*sin(pi/32)/2 + 2**(9/16)*cos(pi/32)/2 - 2**(9/16)*I*cos(pi/32)/2 + 2**(9/16)*I*sin(pi/32)/2,
#  -2**(9/16)*cos(pi/32)/2 - 2**(9/16)*sin(pi/32)/2 - 2**(9/16)*I*sin(pi/32)/2 + 2**(9/16)*I*cos(pi/32)/2,
#  -2**(9/16)*cos(pi/32)/2 + 2**(9/16)*sin(pi/32)/2 - 2**(9/16)*I*cos(pi/32)/2 - 2**(9/16)*I*sin(pi/32)/2]

# %%
answer = []
for i in range(8):
# Out:
# False
# False
# False
# False
# False
# False
# False
# False

# %% [markdown]
# ![](pic/21/3.png)

# %% [markdown]
# ![](pic/21/4.png)

# %%
import sympy as sp
import matplotlib.pyplot as plt
import cmath

I = sp.I

roots_a = [sp.exp(2*sp.pi*I*k/8) for k in range(8)]

z_b = -18 / (1 + I*sp.sqrt(3))
z_b_simplified = sp.simplify(z_b)
roots_b = [sp.root(z_b_simplified, 4, k) for k in range(4)]

expr_c = (1 - 5*I)/(1 + I) - 5*(1 + 2*I)/(2 - I) + 11
expr_c_simplified = sp.simplify(expr_c)
roots_c = [sp.root(expr_c_simplified, 3, k) for k in range(3)]

z_d = 1 - I
roots_d = [sp.root(z_d, 9, k) for k in range(9)]

fig, axes = plt.subplots(2, 2, figsize=(10, 10))

ax = axes[0, 0]
ax.axhline(y=0, color='k', linewidth=0.5)
ax.axvline(x=0, color='k', linewidth=0.5)
vals_a = [complex(r.evalf()) for r in roots_a]
xs_a = [v.real for v in vals_a] + [vals_a[0].real]
ys_a = [v.imag for v in vals_a] + [vals_a[0].imag]
ax.plot(xs_a, ys_a, 'r-', linewidth=1.5, alpha=0.7)
for v in vals_a:
    ax.plot(v.real, v.imag, 'ro', markersize=8)
    ax.plot([0, v.real], [0, v.imag], 'r-', alpha=0.3)
ax.grid(True, alpha=0.3)
ax.set_aspect('equal')

ax = axes[0, 1]
ax.axhline(y=0, color='k', linewidth=0.5)
ax.axvline(x=0, color='k', linewidth=0.5)
vals_b = [complex(r.evalf()) for r in roots_b]
xs_b = [v.real for v in vals_b] + [vals_b[0].real]
ys_b = [v.imag for v in vals_b] + [vals_b[0].imag]
ax.plot(xs_b, ys_b, 'b-', linewidth=1.5, alpha=0.7)
for v in vals_b:
    ax.plot(v.real, v.imag, 'bo', markersize=8)
    ax.plot([0, v.real], [0, v.imag], 'b-', alpha=0.3)
ax.grid(True, alpha=0.3)
ax.set_aspect('equal')

ax = axes[1, 0]
ax.axhline(y=0, color='k', linewidth=0.5)
ax.axvline(x=0, color='k', linewidth=0.5)
vals_c = [complex(r.evalf()) for r in roots_c]
xs_c = [v.real for v in vals_c] + [vals_c[0].real]
ys_c = [v.imag for v in vals_c] + [vals_c[0].imag]
ax.plot(xs_c, ys_c, 'g-', linewidth=1.5, alpha=0.7)
for v in vals_c:
    ax.plot(v.real, v.imag, 'go', markersize=8)
    ax.plot([0, v.real], [0, v.imag], 'g-', alpha=0.3)
ax.grid(True, alpha=0.3)
ax.set_aspect('equal')

ax = axes[1, 1]
ax.axhline(y=0, color='k', linewidth=0.5)
ax.axvline(x=0, color='k', linewidth=0.5)
vals_d = [complex(r.evalf()) for r in roots_d]
xs_d = [v.real for v in vals_d] + [vals_d[0].real]
ys_d = [v.imag for v in vals_d] + [vals_d[0].imag]
ax.plot(xs_d, ys_d, 'm-', linewidth=1.5, alpha=0.7)
for v in vals_d:
    ax.plot(v.real, v.imag, 'mo', markersize=8)
    ax.plot([0, v.real], [0, v.imag], 'm-', alpha=0.3)
ax.grid(True, alpha=0.3)
ax.set_aspect('equal')

plt.tight_layout()
plt.show()

# %%
I = I

roots_a = [exp(2*sp.pi*I*k/8) for k in range(8)]

fig, ax = plt.subplots(figsize=(5, 5))
vals_a = [complex(r.evalf()) for r in roots_a]
xs_a = [v.real for v in vals_a] + [vals_a[0].real]
ys_a = [v.imag for v in vals_a] + [vals_a[0].imag]
ax.plot(xs_a, ys_a, 'r-', linewidth=1, alpha=0.7)
for v in vals_a:
    ax.plot(v.real, v.imag, 'ro', markersize=4)
    ax.plot([0, v.real], [0, v.imag], 'r-', alpha=0.3)
ax.grid(True)
plt.show()

# %%
I = I

z_b = -18 / (1 + I*sqrt(3))
z_b_simplified = simplify(z_b)
roots_b = [sp.root(z_b_simplified, 4, k) for k in range(4)]

fig, ax = plt.subplots(figsize=(5, 5))
vals_b = [complex(r.evalf()) for r in roots_b]
xs_b = [v.real for v in vals_b] + [vals_b[0].real]
ys_b = [v.imag for v in vals_b] + [vals_b[0].imag]
ax.plot(xs_b, ys_b, linewidht=1)
for i in range(len(xs_b)):
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[68], line 11
#       9 xs_b = [v.real for v in vals_b] + [vals_b[0].real]
#      10 ys_b = [v.imag for v in vals_b] + [vals_b[0].imag]
# ---> 11 ax.plot(xs_b, ys_b, linewidht=1)
#      12 plt.show()
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.13/site-packages/matplotlib/axes/_axes.py:1777, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1534 """
#    1535 Plot y versus x as lines and/or markers.
#    1536
#    (...)   1774 (``'green'``) or hex strings (``'#008000'``).
#    1775 """
#    1776 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778 for line in lines:
#    1779     self.add_line(line)
#
# ...

# %%
raise "dawd"
I = sp.I

expr_c = (1 - 5*I)/(1 + I) - 5*(1 + 2*I)/(2 - I) + 11
expr_c_simplified = sp.simplify(expr_c)
roots_c = [sp.root(expr_c_simplified, 3, k) for k in range(3)]

fig, ax = plt.subplots(figsize=(5, 5))
vals_c = [complex(r.evalf()) for r in roots_c]
xs_c = [v.real for v in vals_c] + [vals_c[0].real]
ys_c = [v.imag for v in vals_c] + [vals_c[0].imag]
ax.plot(xs_c, ys_c, 'g-', linewidth=1, alpha=0.7)
for v in vals_c:
    ax.plot(v.real, v.imag, 'go', markersize=8)
    ax.plot([0, v.real], [0, v.imag], 'g-', alpha=0.3)
ax.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 raise "dawd"
#       2 I = sp.I
#       4 expr_c = (1 - 5*I)/(1 + I) - 5*(1 + 2*I)/(2 - I) + 11
#
# TypeError: exceptions must derive from BaseException

# %%
roots_1_4a[0].imag
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 roots_1_4a[0].imag
#
# AttributeError: 'One' object has no attribute 'imag'

# %%
import sympy as sp
import matplotlib.pyplot as plt
import numpy as np

I = sp.I

# Вычисление всех корней
# a) 8-е корни из 1
roots_a = [sp.exp(2*sp.pi*I*k/8) for k in range(8)]
vals_a = [complex(r.evalf()) for r in roots_a]

# b) 4-е корни из -18/(1 + i√3)
z_b = -18 / (1 + I*sp.sqrt(3))
z_b_simplified = sp.simplify(z_b)
roots_b = [sp.root(z_b_simplified, 4, k) for k in range(4)]
vals_b = [complex(r.evalf()) for r in roots_b]

# c) 3-и корни из выражения
expr_c = (1 - 5*I)/(1 + I) - 5*(1 + 2*I)/(2 - I) + 11
expr_c_simplified = sp.simplify(expr_c)
roots_c = [sp.root(expr_c_simplified, 3, k) for k in range(3)]
vals_c = [complex(r.evalf()) for r in roots_c]

# d) 9-е корни из (1 - i)
z_d = 1 - I
roots_d = [sp.root(z_d, 9, k) for k in range(9)]
vals_d = [complex(r.evalf()) for r in roots_d]

# Создание одного графика с 4 подграфиками
fig, axes = plt.subplots(2, 2, figsize=(12, 12))

# Функция для рисования окружности
def draw_circle(ax, center, radius, **kwargs):
    circle = plt.Circle(center, radius, fill=False, **kwargs)
    ax.add_patch(circle)

# a) 8-е корни из 1
ax = axes[0, 0]
ax.axhline(y=0, color='k', linewidth=0.5)
ax.axvline(x=0, color='k', linewidth=0.5)
xs_a = [v.real for v in vals_a] + [vals_a[0].real]
ys_a = [v.imag for v in vals_a] + [vals_a[0].imag]
ax.plot(xs_a, ys_a, 'r-', linewidth=1.5, alpha=0.7)
draw_circle(ax, (0, 0), 1, color='red', linewidth=1, alpha=0.5)
for i, v in enumerate(vals_a):
    ax.plot(v.real, v.imag, 'ro', markersize=8)
    ax.text(v.real*1.1, v.imag*1.1, f'z{i}', fontsize=9, ha='center', va='center', color='red')
    ax.plot([0, v.real], [0, v.imag], 'r-', alpha=0.3)
ax.set_title('a) 8√1', fontsize=12, fontweight='bold')
ax.grid(True, alpha=0.3)
ax.set_aspect('equal')
ax.set_xlim(-1.5, 1.5)
ax.set_ylim(-1.5, 1.5)

# b) 4-е корни из -18/(1 + i√3)
ax = axes[0, 1]
ax.axhline(y=0, color='k', linewidth=0.5)
ax.axvline(x=0, color='k', linewidth=0.5)
xs_b = [v.real for v in vals_b] + [vals_b[0].real]
ys_b = [v.imag for v in vals_b] + [vals_b[0].imag]
ax.plot(xs_b, ys_b, 'b-', linewidth=1.5, alpha=0.7)
radius_b = abs(vals_b[0])
draw_circle(ax, (0, 0), radius_b, color='blue', linewidth=1, alpha=0.5)
for i, v in enumerate(vals_b):
    ax.plot(v.real, v.imag, 'bo', markersize=8)
    ax.text(v.real*1.1, v.imag*1.1, f'z{i}', fontsize=9, ha='center', va='center', color='blue')
    ax.plot([0, v.real], [0, v.imag], 'b-', alpha=0.3)
ax.set_title('b) 4√(-18/(1+i√3))', fontsize=12, fontweight='bold')
ax.grid(True, alpha=0.3)
ax.set_aspect('equal')
ax.set_xlim(-2, 2)
ax.set_ylim(-2, 2)

# c) 3-и корни из выражения
ax = axes[1, 0]
ax.axhline(y=0, color='k', linewidth=0.5)
ax.axvline(x=0, color='k', linewidth=0.5)
xs_c = [v.real for v in vals_c] + [vals_c[0].real]
ys_c = [v.imag for v in vals_c] + [vals_c[0].imag]
ax.plot(xs_c, ys_c, 'g-', linewidth=1.5, alpha=0.7)
radius_c = abs(vals_c[0])
draw_circle(ax, (0, 0), radius_c, color='green', linewidth=1, alpha=0.5)
for i, v in enumerate(vals_c):
    ax.plot(v.real, v.imag, 'go', markersize=8)
    ax.text(v.real*1.1, v.imag*1.1, f'z{i}', fontsize=9, ha='center', va='center', color='green')
    ax.plot([0, v.real], [0, v.imag], 'g-', alpha=0.3)
ax.set_title('c) 3√(...)', fontsize=12, fontweight='bold')
ax.grid(True, alpha=0.3)
ax.set_aspect('equal')
ax.set_xlim(-2, 2)
ax.set_ylim(-2, 2)

# d) 9-е корни из (1 - i)
ax = axes[1, 1]
ax.axhline(y=0, color='k', linewidth=0.5)
ax.axvline(x=0, color='k', linewidth=0.5)
xs_d = [v.real for v in vals_d] + [vals_d[0].real]
ys_d = [v.imag for v in vals_d] + [vals_d[0].imag]
ax.plot(xs_d, ys_d, 'm-', linewidth=1.5, alpha=0.7)
radius_d = abs(vals_d[0])
draw_circle(ax, (0, 0), radius_d, color='magenta', linewidth=1, alpha=0.5)
for i, v in enumerate(vals_d):
    ax.plot(v.real, v.imag, 'mo', markersize=8)
    ax.text(v.real*1.1, v.imag*1.1, f'z{i}', fontsize=9, ha='center', va='center', color='magenta')
    ax.plot([0, v.real], [0, v.imag], 'm-', alpha=0.3)
ax.set_title('d) 9√(1-i)', fontsize=12, fontweight='bold')
ax.grid(True, alpha=0.3)
ax.set_aspect('equal')
ax.set_xlim(-1.5, 1.5)
ax.set_ylim(-1.5, 1.5)

plt.suptitle('Корни из комплексных чисел', fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# %%
import sympy as sp
import matplotlib.pyplot as plt

I = sp.I

# Вычисление всех корней
# a) 8-е корни из 1
roots_a = [sp.exp(2*sp.pi*I*k/8) for k in range(8)]
vals_a = [complex(r.evalf()) for r in roots_a]

# b) 4-е корни из -18/(1 + i√3)
z_b = -18 / (1 + I*sp.sqrt(3))
z_b_simplified = sp.simplify(z_b)
roots_b = [sp.root(z_b_simplified, 4, k) for k in range(4)]
vals_b = [complex(r.evalf()) for r in roots_b]

# c) 3-и корни из выражения
expr_c = (1 - 5*I)/(1 + I) - 5*(1 + 2*I)/(2 - I) + 11
expr_c_simplified = sp.simplify(expr_c)
roots_c = [sp.root(expr_c_simplified, 3, k) for k in range(3)]
vals_c = [complex(r.evalf()) for r in roots_c]

# d) 9-е корни из (1 - i)
z_d = 1 - I
roots_d = [sp.root(z_d, 9, k) for k in range(9)]
vals_d = [complex(r.evalf()) for r in roots_d]

# Создание одного графика с 4 подграфиками
fig, axes = plt.subplots(2, 2, figsize=(12, 12))

# Функция для рисования окружности
def draw_circle(ax, center, radius, **kwargs):
    circle = plt.Circle(center, radius, fill=False, **kwargs)
    ax.add_patch(circle)

# a) 8-е корни из 1
ax = axes[0, 0]
ax.axhline(y=0, color='k', linewidth=0.5)
ax.axvline(x=0, color='k', linewidth=0.5)
xs_a = [v.real for v in vals_a] + [vals_a[0].real]
ys_a = [v.imag for v in vals_a] + [vals_a[0].imag]
ax.plot(xs_a, ys_a, 'r-', linewidth=1.5, alpha=0.7)
draw_circle(ax, (0, 0), 1, color='red', linewidth=1, alpha=0.5)
for i, v in enumerate(vals_a):
    ax.plot(v.real, v.imag, 'ro', markersize=8)
    ax.text(v.real*1.1, v.imag*1.1, f'z{i}', fontsize=9, ha='center', va='center', color='red')
    ax.plot([0, v.real], [0, v.imag], 'r-', alpha=0.3)
ax.set_title('a) 8√1', fontsize=12, fontweight='bold')
ax.grid(True, alpha=0.3)
ax.set_aspect('equal')
ax.set_xlim(-1.5, 1.5)
ax.set_ylim(-1.5, 1.5)

# b) 4-е корни из -18/(1 + i√3)
ax = axes[0, 1]
ax.axhline(y=0, color='k', linewidth=0.5)
ax.axvline(x=0, color='k', linewidth=0.5)
xs_b = [v.real for v in vals_b] + [vals_b[0].real]
ys_b = [v.imag for v in vals_b] + [vals_b[0].imag]
ax.plot(xs_b, ys_b, 'b-', linewidth=1.5, alpha=0.7)
radius_b = abs(vals_b[0])
draw_circle(ax, (0, 0), radius_b, color='blue', linewidth=1, alpha=0.5)
for i, v in enumerate(vals_b):
    ax.plot(v.real, v.imag, 'bo', markersize=8)
    ax.text(v.real*1.1, v.imag*1.1, f'z{i}', fontsize=9, ha='center', va='center', color='blue')
    ax.plot([0, v.real], [0, v.imag], 'b-', alpha=0.3)
ax.set_title('b) 4√(-18/(1+i√3))', fontsize=12, fontweight='bold')
ax.grid(True, alpha=0.3)
ax.set_aspect('equal')
ax.set_xlim(-2, 2)
ax.set_ylim(-2, 2)

# c) 3-и корни из выражения (увеличенный масштаб)
ax = axes[1, 0]
ax.axhline(y=0, color='k', linewidth=0.5)
ax.axvline(x=0, color='k', linewidth=0.5)
xs_c = [v.real for v in vals_c] + [vals_c[0].real]
ys_c = [v.imag for v in vals_c] + [vals_c[0].imag]
ax.plot(xs_c, ys_c, 'g-', linewidth=1.5, alpha=0.7)
radius_c = abs(vals_c[0])
draw_circle(ax, (0, 0), radius_c, color='green', linewidth=1, alpha=0.5)
for i, v in enumerate(vals_c):
    ax.plot(v.real, v.imag, 'ro', markersize=8)
    ax.text(v.real*1.15, v.imag*1.15, f'z{i}', fontsize=10, ha='center', va='center', color='green')
    ax.plot([0, v.real], [0, v.imag], 'g-', alpha=0.3)
ax.set_title('c) 3√(...)', fontsize=12, fontweight='bold')
ax.grid(True, alpha=0.3)
ax.set_aspect('equal')
ax.set_xlim(-4, 4)  # Увеличенный масштаб
ax.set_ylim(-4, 4)  # Увеличенный масштаб

# d) 9-е корни из (1 - i)
ax = axes[1, 1]
ax.axhline(y=0, color='k', linewidth=0.5)
ax.axvline(x=0, color='k', linewidth=0.5)
xs_d = [v.real for v in vals_d] + [vals_d[0].real]
ys_d = [v.imag for v in vals_d] + [vals_d[0].imag]
ax.plot(xs_d, ys_d, 'm-', linewidth=1.5, alpha=0.7)
radius_d = abs(vals_d[0])
draw_circle(ax, (0, 0), radius_d, color='magenta', linewidth=1, alpha=0.5)
for i, v in enumerate(vals_d):
    ax.plot(v.real, v.imag, 'mo', markersize=8)
    ax.text(v.real*1.1, v.imag*1.1, f'z{i}', fontsize=9, ha='center', va='center', color='magenta')
    ax.plot([0, v.real], [0, v.imag], 'm-', alpha=0.3)
ax.set_title('d) 9√(1-i)', fontsize=12, fontweight='bold')
ax.grid(True, alpha=0.3)
ax.set_aspect('equal')
ax.set_xlim(-1.5, 1.5)
ax.set_ylim(-1.5, 1.5)

plt.suptitle('Корни из комплексных чисел', fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# %%
val_1_4b = -18 / (1 + I*sqrt(3))
val_1_4b = simplify(val_1_4b)
modb = Abs(val_1_4b)
radius = modb ** (1/4)
roots_1_4b = [val_1_4b**(1/4) * exp(2*pi*I*k/4) for k in range(4)]
print("1.4.b Корни:", [N(r) for r in roots_1_4b])
# Out:
# 1.4.b Корни: [1.5 + 0.866025403784439*I, -0.866025403784439 + 1.5*I, -1.5 - 0.866025403784439*I, 0.866025403784439 - 1.5*I]

# %%
plot_roots_on_circle(roots_1_4b, radius, "b")

# %% [markdown]
# ![](pic/21/5.png)

# %%
Eq((2-I) / (2+I), 1)
# Out:
# Eq((2 - I)**2/5, 1)

# %% [markdown]
# ![](pic/21/6.png)

# %% [markdown]
# ![](pic/21/7.png)

# %% [markdown]
# ![](pic/21/8.png)

# %% [markdown]
# ![](pic/21/9.png)
